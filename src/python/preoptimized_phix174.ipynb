# %% [markdown]
# ### Parsing Code

# %%
from Bio import Entrez, SeqIO
import pinetree as pt

# %%
from Bio import Entrez, SeqIO
Entrez.email = "tanvi.ingle@utexas.edu"
handle = Entrez.efetch(db="nuccore",
                           id=["MN385565.1"],
                           rettype="gb",
                           retmode="text")

record = SeqIO.read(handle, "genbank")
    
for feature in record.features:
        #print(feature)
        #print(feature.qualifiers.keys())
        print("New Feature")
        print(feature.qualifiers.get("note"))
        print("")
        
        '''
        print(feature.qualifiers.get("regulatory"))
        print("\n")
        print(feature.location)
        print("\n")
        print("\n")
        #print(feature.location.start.position)
        #print(feature.location.end.position)
        '''
# Out:
# New Feature
# None
#
# New Feature
# ['ORF 6; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# None
#
# New Feature
# None
#
# New Feature
# ['ORF 7; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# ['ORF 8; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# ['ORF 9; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# ['ORF 10; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# ['ORF 11; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# None
#
# New Feature
# None
#
# New Feature
# None
#
# New Feature
# None
#
# New Feature
# ['ORF 12; conserved open reading frame determined not to code for a protein during testing']
#
# New Feature
# ...
